# %% [markdown]
# Exercise 5 (Types): Expression and Variables in Python 학번 : 2024274595 성명 : 이재곤

# %% [markdown]
# What is the value of x where x = 3 + 2 * 2

# %%
x = 3+2*2
x
# Out:
# 7

# %% [markdown]
# What is the value of y where y = (3 + 2) * 2?

# %%
 y = (3 + 2) * 2
 y
# Out:
# 10

# %% [markdown]
# What is the value of z where z = x + y?

# %%
z=x+y
z
# Out:
# 17
