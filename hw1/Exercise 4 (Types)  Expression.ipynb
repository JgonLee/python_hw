# %% [markdown]
# Exercise 4 (Types): Expression   학번 :2024274595   성명 : 이재곤

# %% [markdown]
# Let's write an expression that calculates how many hours there are in 160
# minutes:

# %%
160//60
# Out:
# 2
